# %%
import matplotlib.pyplot as plt

# %%
dt_max_depth = [1, 2, 3, 4, 5, 6, 7]

dt_validation_accuracy = [0.44873366013071897,
                      0.4503676470588235,
                      0.44696350762527226,
                      0.4464188453159041,
                      0.4436955337690632,
                      0.44355936819172115,
                      0.44492102396514155]

dt_validation_f1 = [0.6181627416752231,
                0.3841170058570559,
                0.31889416596604925,
                0.3276257363196387,
                0.3115710601099912,
                0.29837834903400673,
                0.28871579620182714]

dt_test_accuracy = [0.44873366013071897,
                   0.4507761437908497,
                   0.44669117647058826,
                   0.44771241830065356,
                   0.44648692810457513,
                   0.44771241830065356,
                   0.44934640522875813]

dt_test_f1 = [0.6186736347102542,
             0.3278244052717115,
             0.30220548164542643,
             0.31321930258669156,
             0.3229585935066397,
             0.2029664716553877,
             0.20699572716781742]

# %%
plt.plot(dt_max_depth, dt_validation_accuracy, 'ro')

# %%
plt.plot(dt_max_depth, dt_validation_f1, 'ro')

# %%
plt.plot(dt_max_depth, dt_test_accuracy, 'ro')

# %%
plt.plot(dt_max_depth, dt_test_f1, 'ro')

# %%
knn_metrics = ['Cosine', 'Manhattan', 'Euclidean']

knn_k = [1, 2, 3, 4, 5, 6, 7, 8]

# when k = 4, see metrics vs performance
knn_metrics_acc_validation = [0.400326, 0.404616, 0.390387]
knn_metrics_f1_validation = [0.243802, 0.231152, 0.223659]
knn_metrics_acc_test = [0.397671, 0.404616, 0.397263]
knn_metrics_f1_test = [0.211263, 0.204961, 0.228794]

# when metrics = Manhattan, see K vs performance
knn_k_acc_validation = [0.388344, 0.388344, 0.386437, 0.398488, 0.403935, 0.414216, 0.413807, 0.413398]
knn_k_f1_validation = [0.211207, 0.211207, 0.203517, 0.231152, 0.238051, 0.246479, 0.242444, 0.249255]

# %%
plt.plot(knn_metrics, knn_metrics_acc_validation, 'ro')

# %%
plt.plot(knn_metrics, knn_metrics_f1_validation, 'ro')

# %%
plt.plot(knn_k, knn_k_acc_validation, 'ro')

# %%
plt.plot(knn_k, knn_k_f1_validation, 'ro')
